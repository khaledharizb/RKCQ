# %%
using Plots, DelimitedFiles

# %%
data1 = readdlm("q_err.dat");
data2 = readdlm("p_err.dat");

# %%
f1(x)=0.2*x^1; f2(x)=x^2; 

plt1=plot(xscale=:log10, yscale=:log10,xlabel="log₁₀(h)",ylabel="log₁₀(error)",grid=false,framestyle=:box,title="BDF1CQ")

plot!(plt1,data1[:,1] , data1[:,2] , m =:sq,label="x1")
plot!(plt1,data1[:,1] ,  data1[:,3] , m =:sq,label="x2")




plt2=plot(xscale=:log10, yscale=:log10,xlabel="log₁₀(h)", ylabel="log₁₀(error)",grid=false,framestyle=:box,title="BDF2CQ")

plot!(plt2,data2[:,1] , data2[:,2] , m =:sq,label="x1")
plot!(plt2,data2[:,1] ,  data2[:,3] , m =:sq,label="x2")


plot(plt1,plt2,layout=(1,2),legend=:topleft)
#savefig("errors.pdf")
